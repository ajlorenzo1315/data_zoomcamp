# %% [markdown]
# ### Importamos pandas

# %%
# !pip install fastparquet pyarrow
# Out:
# Collecting fastparquet
#   Downloading fastparquet-2023.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 3.5 MB/s eta 0:00:01
# Collecting pyarrow
#   Downloading pyarrow-11.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.0 MB)
#      |████████████████████████████████| 35.0 MB 18.8 MB/s eta 0:00:01
# Collecting fsspec
#   Downloading fsspec-2023.4.0-py3-none-any.whl (153 kB)
#      |████████████████████████████████| 153 kB 91.2 MB/s eta 0:00:01
# Requirement already satisfied: packaging in /home/alourido/.local/lib/python3.8/site-packages (from fastparquet) (23.0)
# Requirement already satisfied: numpy>=1.20.3 in /home/alourido/.local/lib/python3.8/site-packages (from fastparquet) (1.24.2)
# Requirement already satisfied: pandas>=1.5.0 in /home/alourido/.local/lib/python3.8/site-packages (from fastparquet) (1.5.3)
# Collecting cramjam>=2.3
#   Downloading cramjam-2.6.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 57.7 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/alourido/.local/lib/python3.8/site-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/alourido/.local/lib/python3.8/site-packages (from pandas>=1.5.0->fastparquet) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas>=1.5.0->fastparquet) (1.14.0)
# Installing collected packages: fsspec, cramjam, fastparquet, pyarrow
# Successfully installed cramjam-2.6.2 fastparquet-2023.2.0 fsspec-2023.4.0 pyarrow-11.0.0

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.3'

# %% [markdown]
# ## Data set [link](https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page)
#
# ###  Taxi yellow 2021 [link](https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-01.parquet)
#
# Descrgamos el sata set

# %%
# !wget https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-01.parquet
# Out:
# --2023-04-17 16:03:29--  https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-01.parquet
# Resolviendo d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)... 18.67.246.167, 18.67.246.47, 18.67.246.186, ...
# Conectando con d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)[18.67.246.167]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 21686067 (21M) [application/x-www-form-urlencoded]
# Guardando como: “yellow_tripdata_2021-01.parquet”
#
# yellow_tripdata_202 100%[===================>]  20,68M  22,2MB/s    en 0,9s
#
# 2023-04-17 16:03:30 (22,2 MB/s) - “yellow_tripdata_2021-01.parquet” guardado [21686067/21686067]

# %%
df = pd.read_parquet("yellow_tripdata_2021-01.parquet")

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1               1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2               1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3               1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4               2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
# ...           ...                  ...                   ...              ...
# 1369764         2  2021-01-31 23:03:00   2021-01-31 23:33:00              NaN
# 1369765         2  2021-01-31 23:29:00   2021-01-31 23:51:00              NaN
# 1369766         2  2021-01-31 23:25:00   2021-01-31 23:38:00              NaN
# 1369767         6  2021-01-31 23:01:06   2021-02-01 00:02:03              NaN
# 1369768         2  2021-01-31 23:08:29   2021-01-31 23:31:22              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 2.10         1.0                  N           142
# 1                 0.20         1.0                  N           238
# 2                14.70         1.0                  N           132
# 3                10.60         1.0                  N           138
# 4                 4.94         1.0                  N            68
# ...                ...         ...                ...           ...
# 1369764           8.89         NaN               None           229
# 1369765           7.43         NaN               None            41
# 1369766           6.26         NaN               None            74
# 1369767          19.70         NaN               None           265
# 1369768           4.68         NaN               None            89
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                  43             2         8.00   3.00      0.5        0.00
# 1                 151             2         3.00   0.50      0.5        0.00
# 2                 165             1        42.00   0.50      0.5        8.65
# 3                 132             1        29.00   0.50      0.5        6.05
# 4                  33             1        16.50   0.50      0.5        4.06
# ...               ...           ...          ...    ...      ...         ...
# 1369764           181             0        27.78   0.00      0.5        7.46
# 1369765            70             0        32.58   0.00      0.5        0.00
# 1369766           137             0        16.85   0.00      0.5        3.90
# 1369767           188             0        53.68   0.00      0.5        0.00
# 1369768            61             0        25.45   2.75      0.5        0.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                0.00                    0.3         11.80
# 1                0.00                    0.3          4.30
# 2                0.00                    0.3         51.95
# 3                0.00                    0.3         36.35
# 4                0.00                    0.3         24.36
# ...               ...                    ...           ...
# 1369764          0.00                    0.3         38.54
# 1369765          6.12                    0.3         39.50
# 1369766          0.00                    0.3         24.05
# 1369767          0.00                    0.3         54.48
# 1369768          0.00                    0.3         29.00
#
#          congestion_surcharge  airport_fee
# 0                         2.5          NaN
# 1                         0.0          NaN
# 2                         0.0          NaN
# 3                         0.0          NaN
# 4                         2.5          NaN
# ...                       ...          ...
# 1369764                   NaN          NaN
# 1369765                   NaN          NaN
# 1369766                   NaN          NaN
# 1369767                   NaN          NaN
# 1369768                   NaN          NaN
#
# [1369769 rows x 19 columns]

# %% [markdown]
# ### pd.io.sql.get_schema()
#
# es una función de Pandas que permite generar un esquema SQL a partir de un DataFrame de Pandas.
#
# La función toma como entrada el DataFrame y un nombre de tabla y devuelve una cadena de caracteres que representa el esquema SQL. La cadena de caracteres generada por la función contiene los nombres de las columnas del DataFrame y sus tipos de datos correspondientes, así como las restricciones de clave primaria si se especifican.
#
# Es útil para generar el esquema de una tabla en una base de datos a partir de los datos de un DataFrame de Pandas. Esto puede ser especialmente útil en situaciones donde se necesita crear una tabla en una base de datos a partir de un conjunto de datos de Pandas.

# %%
esquema_sql=pd.io.sql.get_schema(df, name='yellow_taxi_data_sql')

# %%
print(esquema_sql)
# Out:
# CREATE TABLE "yellow_taxi_data_sql" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TIMESTAMP,
#   "tpep_dropoff_datetime" TIMESTAMP,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "RatecodeID" REAL,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL,
#   "airport_fee" REAL
# )

# %% [markdown]
# La función **pd.to_datetime()** se utiliza para convertir una columna de un DataFrame de pandas en una serie de fecha y hora de pandas. En este caso, **df.tpep_pickup_datetime** es una columna que se supone contiene valores de fecha y hora en formato de cadena.
#
# La función **pd.to_datetime(df.tpep_pickup_datetime)** convierte los valores de esa columna en formato de cadena en valores de fecha y hora de pandas, lo que permite realizar operaciones de fecha y hora sobre ellos. El resultado es una serie de fecha y hora de pandas que se puede asignar de vuelta a la columna original o utilizar en cálculos posteriores.

# %%
pd.to_datetime(df.tpep_pickup_datetime)
# Out:
# 0         2021-01-01 00:30:10
# 1         2021-01-01 00:51:20
# 2         2021-01-01 00:43:30
# 3         2021-01-01 00:15:48
# 4         2021-01-01 00:31:49
#                   ...
# 1369764   2021-01-31 23:03:00
# 1369765   2021-01-31 23:29:00
# 1369766   2021-01-31 23:25:00
# 1369767   2021-01-31 23:01:06
# 1369768   2021-01-31 23:08:29
# Name: tpep_pickup_datetime, Length: 1369769, dtype: datetime64[ns]

# %% [markdown]
# En este caso, la columna **tpep_dropoff_datetime** del DataFrame df se está convirtiendo en un objeto de fecha y hora.

# %%
pd.to_datetime(df.tpep_dropoff_datetime)
# Out:
# 0         2021-01-01 00:36:12
# 1         2021-01-01 00:52:19
# 2         2021-01-01 01:11:06
# 3         2021-01-01 00:31:01
# 4         2021-01-01 00:48:21
#                   ...
# 1369764   2021-01-31 23:33:00
# 1369765   2021-01-31 23:51:00
# 1369766   2021-01-31 23:38:00
# 1369767   2021-02-01 00:02:03
# 1369768   2021-01-31 23:31:22
# Name: tpep_dropoff_datetime, Length: 1369769, dtype: datetime64[ns]

# %%
! pip install sqlalchemy
# Out:
# Collecting sqlalchemy
#   Downloading SQLAlchemy-2.0.9-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 2.6 MB/s eta 0:00:01
# Collecting greenlet!=0.4.17; platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32")))))
#   Downloading greenlet-2.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (618 kB)
#      |████████████████████████████████| 618 kB 12.2 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/alourido/.local/lib/python3.8/site-packages (from sqlalchemy) (4.5.0)
# Installing collected packages: greenlet, sqlalchemy
# Successfully installed greenlet-2.0.2 sqlalchemy-2.0.9

# %%
! pip install psycopg2
# Out:
# Collecting psycopg2
#   Downloading psycopg2-2.9.6.tar.gz (383 kB)
#      |████████████████████████████████| 383 kB 3.0 MB/s eta 0:00:01
# Building wheels for collected packages: psycopg2
#   Building wheel for psycopg2 (setup.py) ... done
#   Created wheel for psycopg2: filename=psycopg2-2.9.6-cp38-cp38-linux_x86_64.whl size=557652 sha256=af7c43f2e06f41dc7fe6137e5f88d8903f8e0ccbd079c61dcb5845a295c3380b
#   Stored in directory: /home/alourido/.cache/pip/wheels/b4/01/c3/2fb9798be76b52c98b2ad9e6f3101b3dcb5286e7901f754e87
# Successfully built psycopg2
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.6

# %%
from sqlalchemy import create_engine

# %% [markdown]
# La función **create_engine** es provista por la biblioteca SQLAlchemy y permite crear una conexión con un motor de base de datos que puede ser utilizado para ejecutar consultas SQL en una base de datos.
#
# El argumento de la función create_engine es una cadena de texto que especifica la URL de la base de datos. La sintaxis general de la URL de la base de datos es la siguiente:
#
# postgresql://usuario:contraseña@host:puerto/nombre_de_la_base_de_datos
#
# En este caso específico, la URL se refiere a una base de datos PostgreSQL que está siendo ejecutada en la máquina local (localhost) en el puerto 5432, con el nombre de usuario "root" y la contraseña "root". La base de datos a la que se desea conectar se llama "ny_taxi".

# %%
engine=create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %% [markdown]
# **engine.connect()** es un método proporcionado por la biblioteca SQLAlchemy que crea una conexión a la base de datos utilizando el motor que se creó previamente con la función **create_engine()**. Una vez que se establece la conexión, se puede ejecutar código SQL para interactuar con la base de datos.

# %%
engine.connect()

# %% [markdown]
# La función **pd.io.sql.get_schema()** se utiliza para generar una declaración SQL CREATE TABLE a partir de un DataFrame de pandas. El primer argumento de la función es el DataFrame que se va a utilizar para generar la declaración CREATE TABLE. El argumento name se utiliza para especificar el nombre de la tabla en la base de datos. Finalmente, el argumento con se utiliza para especificar la conexión de base de datos (un objeto engine creado con create_engine()).
#
# **La función devuelve una cadena de texto que contiene la declaración SQL CREATE TABLE que puede ser utilizada para crear una tabla en la base de datos.**

# %%
esquema_sql=pd.io.sql.get_schema(df, name='yellow_taxi_data_sql',con=engine) 
print(esquema_sql)
# Out:
# CREATE TABLE yellow_taxi_data_sql (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	airport_fee FLOAT(53)
# )

# %%
Pasamos de parquet a csv

# %%
df.to_csv('yellow_tripdata_2021-01.csv')

# %% [markdown]
# Este código carga un archivo Parquet llamado "yellow_tripdata_2021-01.csv" en un objeto pandas DataFrame de manera iterativa en bloques de tamaño 100,000. El parámetro "iterator=True" especifica que el objeto DataFrame debe ser iterado en lugar de cargado por completo en memoria. Esto es útil cuando se trabaja con archivos de gran tamaño que no caben en la memoria RAM disponible.

# %%
df_inter =  pd.read_csv("yellow_tripdata_2021-01.csv",iterator = True ,chunksize= 100000)

# %% [markdown]
# **next(df_inter)** es una función que se usa para iterar a través de un objeto DataFrame generado por la función pd.read_parquet() con el parámetro iterator=True. Cada llamada a **next(df_inter)** devuelve el siguiente objeto DataFrame en la secuencia de datos.
#
# En este caso, df_inter es un objeto iterador generado por pd.read_parquet() con iterator=True y chunksize=100000, lo que significa que leerá el archivo parquet en trozos de 100,000 filas cada uno. La llamada next(df_inter) devuelve el siguiente trozo de 100,000 filas del archivo parquet como un objeto DataFrame, que se asigna a df_new.

# %%
df_new = next(df_inter)

# %%
len(df_new)
# Out:
# 100000

# %% [markdown]
# Estos comandos convierten las columnas 'tpep_pickup_datetime' y 'tpep_dropoff_datetime' del dataframe df_new en objetos datetime de pandas. Esto permite manipular fechas y horas de una manera más conveniente y también es necesario si se quieren ejecutar operaciones de comparación o aritméticas con estas columnas.

# %%
df_new.tpep_pickup_datetime=pd.to_datetime(df_new.tpep_pickup_datetime)
df_new.tpep_dropoff_datetime=pd.to_datetime(df_new.tpep_dropoff_datetime)

# %% [markdown]
# Este código escribe el objeto DataFrame df_new en una tabla en la base de datos SQL que hemos conectado previamente utilizando la función create_engine() de SQLAlchemy.
#
# La función **to_sql()** convierte el objeto DataFrame en una tabla en la base de datos especificada. El argumento name se refiere al nombre de la tabla, y con especifica la conexión a la base de datos. Si if_exists está establecido en 'replace', entonces la tabla existente con el mismo nombre será eliminada y reemplazada con la nueva tabla que se está escribiendo en la base de datos.

# %%
df_new.to_sql(name='yellow_taxi_data_sql',con=engine , if_exists='replace')
# Out:
# 1000

# %% [markdown]
# ahora en una terminal ejecutamos  pgcli -h localhost -p 5432 -u root -d ny_taxi
#
# y deberiamos poder ver :
#
# <pre>
# pgcli -h localhost -p 5432 -u root -d ny_taxi
# Server: PostgreSQL 13.10 (Debian 13.10-1.pgdg110+1)
# Version: 3.5.0
# Home: http://pgcli.com
#
# root@localhost:ny_taxi> \dt
# +--------+----------------------+-------+-------+
# | Schema | Name                 | Type  | Owner |
# |--------+----------------------+-------+-------|
# | public | yellow_taxi_data_sql | table | root  |
# +--------+----------------------+-------+-------+
# SELECT 1
# Time: 0.029s
#
# root@localhost:ny_taxi> \d yellow_taxi_data_sql
# +-----------------------+-----------------------------+-----------+
# | Column                | Type                        | Modifiers |
# |-----------------------+-----------------------------+-----------|
# | index                 | bigint                      |           |
# | Unnamed: 0            | bigint                      |           |
# | VendorID              | bigint                      |           |
# | tpep_pickup_datetime  | timestamp without time zone |           |
# | tpep_dropoff_datetime | timestamp without time zone |           |
# | passenger_count       | double precision            |           |
# | trip_distance         | double precision            |           |
# | RatecodeID            | double precision            |           |
# | store_and_fwd_flag    | text                        |           |
# | PULocationID          | bigint                      |           |
# | DOLocationID          | bigint                      |           |
# | payment_type          | bigint                      |           |
# | fare_amount           | double precision            |           |
# | extra                 | double precision            |           |
# | mta_tax               | double precision            |           |
# | tip_amount            | double precision            |           |
# | tolls_amount          | double precision            |           |
# | improvement_surcharge | double precision            |           |
# | total_amount          | double precision            |           |
# | congestion_surcharge  | double precision            |           |
# :
#
# root@localhost:ny_taxi>
#
#
# </pre>

# %% [markdown]
# ahora
#
# La función **%time** es una función mágica en IPython que se utiliza para medir el tiempo de ejecución de una única instrucción de Python. En este caso, %time se utiliza para medir el tiempo que tarda en ejecutarse la función to_sql() de Pandas para escribir un lote de datos del DataFrame en la tabla de la base de datos.

# %%
# %time df_new.to_sql(name='yellow_taxi_data_sql',con=engine , if_exists='append')
# Out:
# CPU times: user 3.33 s, sys: 22.7 ms, total: 3.35 s
# Wall time: 5.71 s
# 1000

# %% [markdown]
# tras ejecutar esto nuestra base de docker tendra .
#
# <pre>
#  pgcli -h localhost -p 5432 -u root -d ny_taxi
# Server: PostgreSQL 13.10 (Debian 13.10-1.pgdg110+1)
# Version: 3.5.0
# Home: http://pgcli.com
#
# root@localhost:ny_taxi> select COUNT(1) from yellow_taxi_data_sql
# +--------+
# | count  |
# |--------|
# | 200000 |
# +--------+
# SELECT 1
# Time: 0.025s
# root@localhost:ny_taxi>
#
# </pre>

# %% [markdown]
# Bucle infinito para intrpducir chunks

# %%
def chunck(df_new):
    df_new.tpep_pickup_datetime=pd.to_datetime(df_new.tpep_pickup_datetime)
    df_new.tpep_dropoff_datetime=pd.to_datetime(df_new.tpep_dropoff_datetime)
    df_new.to_sql(name='yellow_taxi_data_sql',con=engine , if_exists='append')

# %%
while True:
    df_new=next(df_inter)
    print("Inserted another chunk ..., toma")
    # %time chunck(df_new)
# Out:
# Inserted another chunk ..., toma
# ---------------------------------------------------------------------------
# AdminShutdown                             Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/default.py:748, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     747 def do_execute(self, cursor, statement, parameters, context=None):
# --> 748     cursor.execute(statement, parameters)
#
# AdminShutdown: terminating connection due to administrator command
# server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# File <timed eval>:1
#
# Cell In[47], line 4, in chunck(df_new)
#       2 df_new.tpep_pickup_datetime=pd.to_datetime(df_new.tpep_pickup_datetime)
#       3 df_new.tpep_dropoff_datetime=pd.to_datetime(df_new.tpep_dropoff_datetime)
# ----> 4 df_new.to_sql(name='yellow_taxi_data_sql',con=engine , if_exists='append')
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:2987, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2830 """
#    2831 Write records stored in a DataFrame to a SQL database.
#    2832
#    (...)
#    2983 [(1,), (None,), (2,)]
#    2984 """  # noqa:E501
#    2985 from pandas.io import sql
# -> 2987 return sql.to_sql(
#    2988     self,
#    2989     name,
#    2990     con,
#    2991     schema=schema,
#    2992     if_exists=if_exists,
#    2993     index=index,
#    2994     index_label=index_label,
#    2995     chunksize=chunksize,
#    2996     dtype=dtype,
#    2997     method=method,
#    2998 )
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:695, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     690 elif not isinstance(frame, DataFrame):
#     691     raise NotImplementedError(
#     692         "'frame' argument should be either a Series or a DataFrame"
#     693     )
# --> 695 return pandas_sql.to_sql(
#     696     frame,
#     697     name,
#     698     if_exists=if_exists,
#     699     index=index,
#     700     index_label=index_label,
#     701     schema=schema,
#     702     chunksize=chunksize,
#     703     dtype=dtype,
#     704     method=method,
#     705     engine=engine,
#     706     **engine_kwargs,
#     707 )
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:1728, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1678 """
#    1679 Write records stored in a DataFrame to a SQL database.
#    1680
#    (...)
#    1724     Any additional kwargs are passed to the engine.
#    1725 """
#    1726 sql_engine = get_engine(engine)
# -> 1728 table = self.prep_table(
#    1729     frame=frame,
#    1730     name=name,
#    1731     if_exists=if_exists,
#    1732     index=index,
#    1733     index_label=index_label,
#    1734     schema=schema,
#    1735     dtype=dtype,
#    1736 )
#    1738 total_inserted = sql_engine.insert_records(
#    1739     table=table,
#    1740     con=self.connectable,
#    (...)
#    1747     **engine_kwargs,
#    1748 )
#    1750 self.check_case_sensitive(name=name, schema=schema)
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:1631, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1619             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1621 table = SQLTable(
#    1622     name,
#    1623     self,
#    (...)
#    1629     dtype=dtype,
#    1630 )
# -> 1631 table.create()
#    1632 return table
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:827, in SQLTable.create(self)
#     826 def create(self) -> None:
# --> 827     if self.exists():
#     828         if self.if_exists == "fail":
#     829             raise ValueError(f"Table '{self.name}' already exists.")
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:814, in SQLTable.exists(self)
#     813 def exists(self):
# --> 814     return self.pd_sql.has_table(self.name, self.schema)
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:1761, in SQLDatabase.has_table(self, name, schema)
#    1758 from sqlalchemy import inspect as sqlalchemy_inspect
#    1760 insp = sqlalchemy_inspect(self.connectable)
# -> 1761 return insp.has_table(name, schema or self.meta.schema)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/reflection.py:430, in Inspector.has_table(self, table_name, schema, **kw)
#     404 r"""Return True if the backend has a table, view, or temporary
#     405 table of the given name.
#     406
#    (...)
#     427
#     428 """
#     429 with self._operation_context() as conn:
# --> 430     return self.dialect.has_table(
#     431         conn, table_name, schema, info_cache=self.info_cache, **kw
#     432     )
#
# File <string>:2, in has_table(self, connection, table_name, schema, **kw)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/reflection.py:97, in cache(fn, self, con, *args, **kw)
#      95 ret: _R = info_cache.get(key)
#      96 if ret is None:
# ---> 97     ret = fn(self, con, *args, **kw)
#      98     info_cache[key] = ret
#      99 return ret
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/base.py:3176, in PGDialect.has_table(self, connection, table_name, schema, **kw)
#    3174 self._ensure_has_table_connection(connection)
#    3175 query = self._has_table_query(schema)
# -> 3176 return bool(connection.scalar(query, {"table_name": table_name}))
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1299, in Connection.scalar(self, statement, parameters, execution_options)
#    1297     raise exc.ObjectNotExecutableError(statement) from err
#    1298 else:
# -> 1299     return meth(
#    1300         self,
#    1301         distilled_parameters,
#    1302         execution_options or NO_OPTIONS,
#    1303     )
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/sql/elements.py:504, in ClauseElement._execute_on_scalar(self, connection, distilled_params, execution_options)
#     492 def _execute_on_scalar(
#     493     self,
#     494     connection: Connection,
#     495     distilled_params: _CoreMultiExecuteParams,
#     496     execution_options: CoreExecuteOptionsParameter,
#     497 ) -> Any:
#     498     """an additional hook for subclasses to provide a different
#     499     implementation for connection.scalar() vs. connection.execute().
#     500
#     501     .. versionadded:: 2.0
#     502
#     503     """
# --> 504     return self._execute_on_connection(
#     505         connection, distilled_params, execution_options
#     506     ).scalar()
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/sql/elements.py:486, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     484     if TYPE_CHECKING:
#     485         assert isinstance(self, Executable)
# --> 486     return connection._execute_clauseelement(
#     487         self, distilled_params, execution_options
#     488     )
#     489 else:
#     490     raise exc.ObjectNotExecutableError(self)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1638, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1626 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1627     "compiled_cache", self.engine._compiled_cache
#    1628 )
#    1630 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1631     dialect=dialect,
#    1632     compiled_cache=compiled_cache,
#    (...)
#    1636     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1637 )
# -> 1638 ret = self._execute_context(
#    1639     dialect,
#    1640     dialect.execution_ctx_cls._init_compiled,
#    1641     compiled_sql,
#    1642     distilled_parameters,
#    1643     execution_options,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     elem,
#    1647     extracted_params,
#    1648     cache_hit=cache_hit,
#    1649 )
#    1650 if has_events:
#    1651     self.dispatch.after_execute(
#    1652         self,
#    1653         elem,
#    (...)
#    1657         ret,
#    1658     )
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1842, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1837     return self._exec_insertmany_context(
#    1838         dialect,
#    1839         context,
#    1840     )
#    1841 else:
# -> 1842     return self._exec_single_context(
#    1843         dialect, context, statement, parameters
#    1844     )
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1983, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1980     result = context._setup_result_proxy()
#    1982 except BaseException as e:
# -> 1983     self._handle_dbapi_exception(
#    1984         e, str_statement, effective_parameters, cursor, context
#    1985     )
#    1987 return result
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:2326, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2324 elif should_wrap:
#    2325     assert sqlalchemy_exception is not None
# -> 2326     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2327 else:
#    2328     assert exc_info[1] is not None
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1962                 break
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#    1969     self.dispatch.after_cursor_execute(
#    1970         self,
#    1971         cursor,
#    (...)
#    1975         context.executemany,
#    1976     )
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/default.py:748, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     747 def do_execute(self, cursor, statement, parameters, context=None):
# --> 748     cursor.execute(statement, parameters)
#
# OperationalError: (psycopg2.errors.AdminShutdown) terminating connection due to administrator command
# server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.
#
# [SQL: SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s]
# [parameters: {'table_name': 'yellow_taxi_data_sql', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Inserted another chunk ..., toma
# CPU times: user 3.3 s, sys: 43.8 ms, total: 3.34 s
# Wall time: 5.89 s
# Inserted another chunk ..., toma
# CPU times: user 3.37 s, sys: 43.9 ms, total: 3.41 s
# Wall time: 5.78 s
# Inserted another chunk ..., toma
# CPU times: user 3.42 s, sys: 39.6 ms, total: 3.46 s
# Wall time: 5.86 s
# Inserted another chunk ..., toma
# CPU times: user 3.31 s, sys: 27.9 ms, total: 3.34 s
# Wall time: 5.72 s
# Inserted another chunk ..., toma
# CPU times: user 3.33 s, sys: 31.6 ms, total: 3.36 s
# Wall time: 5.8 s
# Inserted another chunk ..., toma
# CPU times: user 3.56 s, sys: 19.5 ms, total: 3.58 s
# Wall time: 6.1 s
# Inserted another chunk ..., toma
# CPU times: user 3.6 s, sys: 31.8 ms, total: 3.63 s
# Wall time: 6.12 s
# Inserted another chunk ..., toma
# ---------------------------------------------------------------------------
# AdminShutdown                             Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/default.py:748, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     747 def do_execute(self, cursor, statement, parameters, context=None):
# --> 748     cursor.execute(statement, parameters)
#
# AdminShutdown: terminating connection due to administrator command
# server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# File <timed eval>:1
#
# Cell In[47], line 4, in chunck(df_new)
#       2 df_new.tpep_pickup_datetime=pd.to_datetime(df_new.tpep_pickup_datetime)
#       3 df_new.tpep_dropoff_datetime=pd.to_datetime(df_new.tpep_dropoff_datetime)
# ----> 4 df_new.to_sql(name='yellow_taxi_data_sql',con=engine , if_exists='append')
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:2987, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2830 """
#    2831 Write records stored in a DataFrame to a SQL database.
#    2832
#    (...)
#    2983 [(1,), (None,), (2,)]
#    2984 """  # noqa:E501
#    2985 from pandas.io import sql
# -> 2987 return sql.to_sql(
#    2988     self,
#    2989     name,
#    2990     con,
#    2991     schema=schema,
#    2992     if_exists=if_exists,
#    2993     index=index,
#    2994     index_label=index_label,
#    2995     chunksize=chunksize,
#    2996     dtype=dtype,
#    2997     method=method,
#    2998 )
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:695, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     690 elif not isinstance(frame, DataFrame):
#     691     raise NotImplementedError(
#     692         "'frame' argument should be either a Series or a DataFrame"
#     693     )
# --> 695 return pandas_sql.to_sql(
#     696     frame,
#     697     name,
#     698     if_exists=if_exists,
#     699     index=index,
#     700     index_label=index_label,
#     701     schema=schema,
#     702     chunksize=chunksize,
#     703     dtype=dtype,
#     704     method=method,
#     705     engine=engine,
#     706     **engine_kwargs,
#     707 )
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:1728, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1678 """
#    1679 Write records stored in a DataFrame to a SQL database.
#    1680
#    (...)
#    1724     Any additional kwargs are passed to the engine.
#    1725 """
#    1726 sql_engine = get_engine(engine)
# -> 1728 table = self.prep_table(
#    1729     frame=frame,
#    1730     name=name,
#    1731     if_exists=if_exists,
#    1732     index=index,
#    1733     index_label=index_label,
#    1734     schema=schema,
#    1735     dtype=dtype,
#    1736 )
#    1738 total_inserted = sql_engine.insert_records(
#    1739     table=table,
#    1740     con=self.connectable,
#    (...)
#    1747     **engine_kwargs,
#    1748 )
#    1750 self.check_case_sensitive(name=name, schema=schema)
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:1631, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1619             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1621 table = SQLTable(
#    1622     name,
#    1623     self,
#    (...)
#    1629     dtype=dtype,
#    1630 )
# -> 1631 table.create()
#    1632 return table
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:827, in SQLTable.create(self)
#     826 def create(self) -> None:
# --> 827     if self.exists():
#     828         if self.if_exists == "fail":
#     829             raise ValueError(f"Table '{self.name}' already exists.")
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:814, in SQLTable.exists(self)
#     813 def exists(self):
# --> 814     return self.pd_sql.has_table(self.name, self.schema)
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:1761, in SQLDatabase.has_table(self, name, schema)
#    1758 from sqlalchemy import inspect as sqlalchemy_inspect
#    1760 insp = sqlalchemy_inspect(self.connectable)
# -> 1761 return insp.has_table(name, schema or self.meta.schema)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/reflection.py:430, in Inspector.has_table(self, table_name, schema, **kw)
#     404 r"""Return True if the backend has a table, view, or temporary
#     405 table of the given name.
#     406
#    (...)
#     427
#     428 """
#     429 with self._operation_context() as conn:
# --> 430     return self.dialect.has_table(
#     431         conn, table_name, schema, info_cache=self.info_cache, **kw
#     432     )
#
# File <string>:2, in has_table(self, connection, table_name, schema, **kw)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/reflection.py:97, in cache(fn, self, con, *args, **kw)
#      95 ret: _R = info_cache.get(key)
#      96 if ret is None:
# ---> 97     ret = fn(self, con, *args, **kw)
#      98     info_cache[key] = ret
#      99 return ret
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/base.py:3176, in PGDialect.has_table(self, connection, table_name, schema, **kw)
#    3174 self._ensure_has_table_connection(connection)
#    3175 query = self._has_table_query(schema)
# -> 3176 return bool(connection.scalar(query, {"table_name": table_name}))
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1299, in Connection.scalar(self, statement, parameters, execution_options)
#    1297     raise exc.ObjectNotExecutableError(statement) from err
#    1298 else:
# -> 1299     return meth(
#    1300         self,
#    1301         distilled_parameters,
#    1302         execution_options or NO_OPTIONS,
#    1303     )
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/sql/elements.py:504, in ClauseElement._execute_on_scalar(self, connection, distilled_params, execution_options)
#     492 def _execute_on_scalar(
#     493     self,
#     494     connection: Connection,
#     495     distilled_params: _CoreMultiExecuteParams,
#     496     execution_options: CoreExecuteOptionsParameter,
#     497 ) -> Any:
#     498     """an additional hook for subclasses to provide a different
#     499     implementation for connection.scalar() vs. connection.execute().
#     500
#     501     .. versionadded:: 2.0
#     502
#     503     """
# --> 504     return self._execute_on_connection(
#     505         connection, distilled_params, execution_options
#     506     ).scalar()
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/sql/elements.py:486, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     484     if TYPE_CHECKING:
#     485         assert isinstance(self, Executable)
# --> 486     return connection._execute_clauseelement(
#     487         self, distilled_params, execution_options
#     488     )
#     489 else:
#     490     raise exc.ObjectNotExecutableError(self)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1638, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1626 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1627     "compiled_cache", self.engine._compiled_cache
#    1628 )
#    1630 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1631     dialect=dialect,
#    1632     compiled_cache=compiled_cache,
#    (...)
#    1636     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1637 )
# -> 1638 ret = self._execute_context(
#    1639     dialect,
#    1640     dialect.execution_ctx_cls._init_compiled,
#    1641     compiled_sql,
#    1642     distilled_parameters,
#    1643     execution_options,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     elem,
#    1647     extracted_params,
#    1648     cache_hit=cache_hit,
#    1649 )
#    1650 if has_events:
#    1651     self.dispatch.after_execute(
#    1652         self,
#    1653         elem,
#    (...)
#    1657         ret,
#    1658     )
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1842, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1837     return self._exec_insertmany_context(
#    1838         dialect,
#    1839         context,
#    1840     )
#    1841 else:
# -> 1842     return self._exec_single_context(
#    1843         dialect, context, statement, parameters
#    1844     )
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1983, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1980     result = context._setup_result_proxy()
#    1982 except BaseException as e:
# -> 1983     self._handle_dbapi_exception(
#    1984         e, str_statement, effective_parameters, cursor, context
#    1985     )
#    1987 return result
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:2326, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2324 elif should_wrap:
#    2325     assert sqlalchemy_exception is not None
# -> 2326     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2327 else:
#    2328     assert exc_info[1] is not None
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1962                 break
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#    1969     self.dispatch.after_cursor_execute(
#    1970         self,
#    1971         cursor,
#    (...)
#    1975         context.executemany,
#    1976     )
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/default.py:748, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     747 def do_execute(self, cursor, statement, parameters, context=None):
# --> 748     cursor.execute(statement, parameters)
#
# OperationalError: (psycopg2.errors.AdminShutdown) terminating connection due to administrator command
# server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.
#
# [SQL: SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s]
# [parameters: {'table_name': 'yellow_taxi_data_sql', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Inserted another chunk ..., toma
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:3275, in Engine.raw_connection(self)
#    3254 """Return a "raw" DBAPI connection from the connection pool.
#    3255
#    3256 The returned object is a proxied version of the DBAPI
#    (...)
#    3273
#    3274 """
# -> 3275 return self.pool.connect()
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:455, in Pool.connect(self)
#     448 """Return a DBAPI connection from the pool.
#     449
#     450 The connection is instrumented such that when its
#    (...)
#     453
#     454 """
# --> 455 return _ConnectionFairy._checkout(self)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:1271, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1270 if not fairy:
# -> 1271     fairy = _ConnectionRecord.checkout(pool)
#    1273     if threadconns is not None:
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:725, in _ConnectionRecord.checkout(cls, pool)
#     724 with util.safe_reraise():
# --> 725     rec._checkin_failed(err, _fairy_was_created=False)
#     727 # not reached, for code linters only
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:722, in _ConnectionRecord.checkout(cls, pool)
#     721 try:
# --> 722     dbapi_connection = rec.get_connection()
#     723 except BaseException as err:
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:842, in _ConnectionRecord.get_connection(self)
#     841     self.info.clear()  # type: ignore  # our info is always present
# --> 842     self.__connect()
#     843 elif (
#     844     self.__pool._recycle > -1
#     845     and time.time() - self.starttime > self.__pool._recycle
#     846 ):
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:906, in _ConnectionRecord.__connect(self)
#     905     with util.safe_reraise():
# --> 906         pool.logger.debug("Error on connect(): %s", e)
#     907 else:
#     908     # in SQLAlchemy 1.4 the first_connect event is not used by
#     909     # the engine, so this will usually not be set
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:901, in _ConnectionRecord.__connect(self)
#     900 self.starttime = time.time()
# --> 901 self.dbapi_connection = connection = pool._invoke_creator(self)
#     902 pool.logger.debug("Created new connection %r", connection)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/create.py:636, in create_engine.<locals>.connect(connection_record)
#     634             return connection
# --> 636 return dialect.connect(*cargs, **cparams)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/default.py:580, in DefaultDialect.connect(self, *cargs, **cparams)
#     578 def connect(self, *cargs, **cparams):
#     579     # inherits the docstring from interfaces.Dialect.connect
# --> 580     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~/.local/lib/python3.8/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#
# OperationalError: could not connect to server: Connection refused
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# File <timed eval>:1
#
# Cell In[47], line 4, in chunck(df_new)
#       2 df_new.tpep_pickup_datetime=pd.to_datetime(df_new.tpep_pickup_datetime)
#       3 df_new.tpep_dropoff_datetime=pd.to_datetime(df_new.tpep_dropoff_datetime)
# ----> 4 df_new.to_sql(name='yellow_taxi_data_sql',con=engine , if_exists='append')
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:2987, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2830 """
#    2831 Write records stored in a DataFrame to a SQL database.
#    2832
#    (...)
#    2983 [(1,), (None,), (2,)]
#    2984 """  # noqa:E501
#    2985 from pandas.io import sql
# -> 2987 return sql.to_sql(
#    2988     self,
#    2989     name,
#    2990     con,
#    2991     schema=schema,
#    2992     if_exists=if_exists,
#    2993     index=index,
#    2994     index_label=index_label,
#    2995     chunksize=chunksize,
#    2996     dtype=dtype,
#    2997     method=method,
#    2998 )
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:695, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     690 elif not isinstance(frame, DataFrame):
#     691     raise NotImplementedError(
#     692         "'frame' argument should be either a Series or a DataFrame"
#     693     )
# --> 695 return pandas_sql.to_sql(
#     696     frame,
#     697     name,
#     698     if_exists=if_exists,
#     699     index=index,
#     700     index_label=index_label,
#     701     schema=schema,
#     702     chunksize=chunksize,
#     703     dtype=dtype,
#     704     method=method,
#     705     engine=engine,
#     706     **engine_kwargs,
#     707 )
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:1728, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1678 """
#    1679 Write records stored in a DataFrame to a SQL database.
#    1680
#    (...)
#    1724     Any additional kwargs are passed to the engine.
#    1725 """
#    1726 sql_engine = get_engine(engine)
# -> 1728 table = self.prep_table(
#    1729     frame=frame,
#    1730     name=name,
#    1731     if_exists=if_exists,
#    1732     index=index,
#    1733     index_label=index_label,
#    1734     schema=schema,
#    1735     dtype=dtype,
#    1736 )
#    1738 total_inserted = sql_engine.insert_records(
#    1739     table=table,
#    1740     con=self.connectable,
#    (...)
#    1747     **engine_kwargs,
#    1748 )
#    1750 self.check_case_sensitive(name=name, schema=schema)
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:1631, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1619             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1621 table = SQLTable(
#    1622     name,
#    1623     self,
#    (...)
#    1629     dtype=dtype,
#    1630 )
# -> 1631 table.create()
#    1632 return table
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:827, in SQLTable.create(self)
#     826 def create(self) -> None:
# --> 827     if self.exists():
#     828         if self.if_exists == "fail":
#     829             raise ValueError(f"Table '{self.name}' already exists.")
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:814, in SQLTable.exists(self)
#     813 def exists(self):
# --> 814     return self.pd_sql.has_table(self.name, self.schema)
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:1760, in SQLDatabase.has_table(self, name, schema)
#    1757 def has_table(self, name: str, schema: str | None = None):
#    1758     from sqlalchemy import inspect as sqlalchemy_inspect
# -> 1760     insp = sqlalchemy_inspect(self.connectable)
#    1761     return insp.has_table(name, schema or self.meta.schema)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/inspection.py:111, in inspect(subject, raiseerr)
#     109 elif reg is True:
#     110     return subject
# --> 111 ret = reg(subject)
#     112 if ret is not None:
#     113     return ret
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/reflection.py:304, in Inspector._engine_insp(bind)
#     302 @inspection._inspects(Engine)
#     303 def _engine_insp(bind: Engine) -> Inspector:  # type: ignore[misc]
# --> 304     return Inspector._construct(Inspector._init_engine, bind)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/reflection.py:237, in Inspector._construct(cls, init, bind)
#     234     cls = bind.dialect.inspector  # type: ignore[attr-defined]
#     236 self = cls.__new__(cls)
# --> 237 init(self, bind)
#     238 return self
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/reflection.py:248, in Inspector._init_engine(self, engine)
#     246 def _init_engine(self, engine: Engine) -> None:
#     247     self.bind = self.engine = engine
# --> 248     engine.connect().close()
#     249     self._op_context_requires_connect = True
#     250     self.dialect = self.engine.dialect
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:3251, in Engine.connect(self)
#    3228 def connect(self) -> Connection:
#    3229     """Return a new :class:`_engine.Connection` object.
#    3230
#    3231     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3248
#    3249     """
# -> 3251     return self._connection_cls(self)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:147, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
# --> 147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#     150         raise
#     151 else:
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:2413, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2411 elif should_wrap:
#    2412     assert sqlalchemy_exception is not None
# -> 2413     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2414 else:
#    2415     assert exc_info[1] is not None
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 if connection is None:
#     144     try:
# --> 145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
#     147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:3275, in Engine.raw_connection(self)
#    3253 def raw_connection(self) -> PoolProxiedConnection:
#    3254     """Return a "raw" DBAPI connection from the connection pool.
#    3255
#    3256     The returned object is a proxied version of the DBAPI
#    (...)
#    3273
#    3274     """
# -> 3275     return self.pool.connect()
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:455, in Pool.connect(self)
#     447 def connect(self) -> PoolProxiedConnection:
#     448     """Return a DBAPI connection from the pool.
#     449
#     450     The connection is instrumented such that when its
#    (...)
#     453
#     454     """
# --> 455     return _ConnectionFairy._checkout(self)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:1271, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1262 @classmethod
#    1263 def _checkout(
#    1264     cls,
#    (...)
#    1267     fairy: Optional[_ConnectionFairy] = None,
#    1268 ) -> _ConnectionFairy:
#    1270     if not fairy:
# -> 1271         fairy = _ConnectionRecord.checkout(pool)
#    1273         if threadconns is not None:
#    1274             threadconns.current = weakref.ref(fairy)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:725, in _ConnectionRecord.checkout(cls, pool)
#     723 except BaseException as err:
#     724     with util.safe_reraise():
# --> 725         rec._checkin_failed(err, _fairy_was_created=False)
#     727     # not reached, for code linters only
#     728     raise
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     assert exc_value is not None
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#     149     self._exc_info = None  # remove potential circular references
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:722, in _ConnectionRecord.checkout(cls, pool)
#     719     rec = pool._do_get()
#     721 try:
# --> 722     dbapi_connection = rec.get_connection()
#     723 except BaseException as err:
#     724     with util.safe_reraise():
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:842, in _ConnectionRecord.get_connection(self)
#     840 if self.dbapi_connection is None:
#     841     self.info.clear()  # type: ignore  # our info is always present
# --> 842     self.__connect()
#     843 elif (
#     844     self.__pool._recycle > -1
#     845     and time.time() - self.starttime > self.__pool._recycle
#     846 ):
#     847     self.__pool.logger.info(
#     848         "Connection %r exceeded timeout; recycling",
#     849         self.dbapi_connection,
#     850     )
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:906, in _ConnectionRecord.__connect(self)
#     904 except BaseException as e:
#     905     with util.safe_reraise():
# --> 906         pool.logger.debug("Error on connect(): %s", e)
#     907 else:
#     908     # in SQLAlchemy 1.4 the first_connect event is not used by
#     909     # the engine, so this will usually not be set
#     910     if pool.dispatch.first_connect:
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     assert exc_value is not None
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#     149     self._exc_info = None  # remove potential circular references
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:901, in _ConnectionRecord.__connect(self)
#     899 try:
#     900     self.starttime = time.time()
# --> 901     self.dbapi_connection = connection = pool._invoke_creator(self)
#     902     pool.logger.debug("Created new connection %r", connection)
#     903     self.fresh = True
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/create.py:636, in create_engine.<locals>.connect(connection_record)
#     633         if connection is not None:
#     634             return connection
# --> 636 return dialect.connect(*cargs, **cparams)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/default.py:580, in DefaultDialect.connect(self, *cargs, **cparams)
#     578 def connect(self, *cargs, **cparams):
#     579     # inherits the docstring from interfaces.Dialect.connect
# --> 580     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~/.local/lib/python3.8/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) could not connect to server: Connection refused
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Inserted another chunk ..., toma
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:3275, in Engine.raw_connection(self)
#    3254 """Return a "raw" DBAPI connection from the connection pool.
#    3255
#    3256 The returned object is a proxied version of the DBAPI
#    (...)
#    3273
#    3274 """
# -> 3275 return self.pool.connect()
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:455, in Pool.connect(self)
#     448 """Return a DBAPI connection from the pool.
#     449
#     450 The connection is instrumented such that when its
#    (...)
#     453
#     454 """
# --> 455 return _ConnectionFairy._checkout(self)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:1271, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1270 if not fairy:
# -> 1271     fairy = _ConnectionRecord.checkout(pool)
#    1273     if threadconns is not None:
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:725, in _ConnectionRecord.checkout(cls, pool)
#     724 with util.safe_reraise():
# --> 725     rec._checkin_failed(err, _fairy_was_created=False)
#     727 # not reached, for code linters only
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:722, in _ConnectionRecord.checkout(cls, pool)
#     721 try:
# --> 722     dbapi_connection = rec.get_connection()
#     723 except BaseException as err:
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:842, in _ConnectionRecord.get_connection(self)
#     841     self.info.clear()  # type: ignore  # our info is always present
# --> 842     self.__connect()
#     843 elif (
#     844     self.__pool._recycle > -1
#     845     and time.time() - self.starttime > self.__pool._recycle
#     846 ):
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:906, in _ConnectionRecord.__connect(self)
#     905     with util.safe_reraise():
# --> 906         pool.logger.debug("Error on connect(): %s", e)
#     907 else:
#     908     # in SQLAlchemy 1.4 the first_connect event is not used by
#     909     # the engine, so this will usually not be set
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:901, in _ConnectionRecord.__connect(self)
#     900 self.starttime = time.time()
# --> 901 self.dbapi_connection = connection = pool._invoke_creator(self)
#     902 pool.logger.debug("Created new connection %r", connection)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/create.py:636, in create_engine.<locals>.connect(connection_record)
#     634             return connection
# --> 636 return dialect.connect(*cargs, **cparams)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/default.py:580, in DefaultDialect.connect(self, *cargs, **cparams)
#     578 def connect(self, *cargs, **cparams):
#     579     # inherits the docstring from interfaces.Dialect.connect
# --> 580     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~/.local/lib/python3.8/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#
# OperationalError: could not connect to server: Connection refused
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# File <timed eval>:1
#
# Cell In[47], line 4, in chunck(df_new)
#       2 df_new.tpep_pickup_datetime=pd.to_datetime(df_new.tpep_pickup_datetime)
#       3 df_new.tpep_dropoff_datetime=pd.to_datetime(df_new.tpep_dropoff_datetime)
# ----> 4 df_new.to_sql(name='yellow_taxi_data_sql',con=engine , if_exists='append')
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:2987, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2830 """
#    2831 Write records stored in a DataFrame to a SQL database.
#    2832
#    (...)
#    2983 [(1,), (None,), (2,)]
#    2984 """  # noqa:E501
#    2985 from pandas.io import sql
# -> 2987 return sql.to_sql(
#    2988     self,
#    2989     name,
#    2990     con,
#    2991     schema=schema,
#    2992     if_exists=if_exists,
#    2993     index=index,
#    2994     index_label=index_label,
#    2995     chunksize=chunksize,
#    2996     dtype=dtype,
#    2997     method=method,
#    2998 )
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:695, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     690 elif not isinstance(frame, DataFrame):
#     691     raise NotImplementedError(
#     692         "'frame' argument should be either a Series or a DataFrame"
#     693     )
# --> 695 return pandas_sql.to_sql(
#     696     frame,
#     697     name,
#     698     if_exists=if_exists,
#     699     index=index,
#     700     index_label=index_label,
#     701     schema=schema,
#     702     chunksize=chunksize,
#     703     dtype=dtype,
#     704     method=method,
#     705     engine=engine,
#     706     **engine_kwargs,
#     707 )
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:1728, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1678 """
#    1679 Write records stored in a DataFrame to a SQL database.
#    1680
#    (...)
#    1724     Any additional kwargs are passed to the engine.
#    1725 """
#    1726 sql_engine = get_engine(engine)
# -> 1728 table = self.prep_table(
#    1729     frame=frame,
#    1730     name=name,
#    1731     if_exists=if_exists,
#    1732     index=index,
#    1733     index_label=index_label,
#    1734     schema=schema,
#    1735     dtype=dtype,
#    1736 )
#    1738 total_inserted = sql_engine.insert_records(
#    1739     table=table,
#    1740     con=self.connectable,
#    (...)
#    1747     **engine_kwargs,
#    1748 )
#    1750 self.check_case_sensitive(name=name, schema=schema)
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:1631, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1619             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1621 table = SQLTable(
#    1622     name,
#    1623     self,
#    (...)
#    1629     dtype=dtype,
#    1630 )
# -> 1631 table.create()
#    1632 return table
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:827, in SQLTable.create(self)
#     826 def create(self) -> None:
# --> 827     if self.exists():
#     828         if self.if_exists == "fail":
#     829             raise ValueError(f"Table '{self.name}' already exists.")
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:814, in SQLTable.exists(self)
#     813 def exists(self):
# --> 814     return self.pd_sql.has_table(self.name, self.schema)
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:1760, in SQLDatabase.has_table(self, name, schema)
# ...
#     723 except BaseException as err:
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:842, in _ConnectionRecord.get_connection(self)
#     841     self.info.clear()  # type: ignore  # our info is always present
# --> 842     self.__connect()
#     843 elif (
#     844     self.__pool._recycle > -1
#     845     and time.time() - self.starttime > self.__pool._recycle
#     846 ):
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:906, in _ConnectionRecord.__connect(self)
#     905     with util.safe_reraise():
# --> 906         pool.logger.debug("Error on connect(): %s", e)
#     907 else:
#     908     # in SQLAlchemy 1.4 the first_connect event is not used by
#     909     # the engine, so this will usually not be set
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:901, in _ConnectionRecord.__connect(self)
#     900 self.starttime = time.time()
# --> 901 self.dbapi_connection = connection = pool._invoke_creator(self)
#     902 pool.logger.debug("Created new connection %r", connection)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/create.py:636, in create_engine.<locals>.connect(connection_record)
#     634             return connection
# --> 636 return dialect.connect(*cargs, **cparams)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/default.py:580, in DefaultDialect.connect(self, *cargs, **cparams)
#     578 def connect(self, *cargs, **cparams):
#     579     # inherits the docstring from interfaces.Dialect.connect
# --> 580     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~/.local/lib/python3.8/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#
# OperationalError: could not connect to server: Connection refused
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# File <timed eval>:1
#
# Cell In[47], line 4, in chunck(df_new)
#       2 df_new.tpep_pickup_datetime=pd.to_datetime(df_new.tpep_pickup_datetime)
#       3 df_new.tpep_dropoff_datetime=pd.to_datetime(df_new.tpep_dropoff_datetime)
# ----> 4 df_new.to_sql(name='yellow_taxi_data_sql',con=engine , if_exists='append')
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:2987, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2830 """
#    2831 Write records stored in a DataFrame to a SQL database.
#    2832
#    (...)
#    2983 [(1,), (None,), (2,)]
#    2984 """  # noqa:E501
#    2985 from pandas.io import sql
# -> 2987 return sql.to_sql(
#    2988     self,
#    2989     name,
#    2990     con,
#    2991     schema=schema,
#    2992     if_exists=if_exists,
#    2993     index=index,
#    2994     index_label=index_label,
#    2995     chunksize=chunksize,
#    2996     dtype=dtype,
#    2997     method=method,
#    2998 )
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:695, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     690 elif not isinstance(frame, DataFrame):
#     691     raise NotImplementedError(
#     692         "'frame' argument should be either a Series or a DataFrame"
#     693     )
# --> 695 return pandas_sql.to_sql(
#     696     frame,
#     697     name,
#     698     if_exists=if_exists,
#     699     index=index,
#     700     index_label=index_label,
#     701     schema=schema,
#     702     chunksize=chunksize,
#     703     dtype=dtype,
#     704     method=method,
#     705     engine=engine,
#     706     **engine_kwargs,
#     707 )
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:1728, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1678 """
#    1679 Write records stored in a DataFrame to a SQL database.
#    1680
#    (...)
#    1724     Any additional kwargs are passed to the engine.
#    1725 """
#    1726 sql_engine = get_engine(engine)
# -> 1728 table = self.prep_table(
#    1729     frame=frame,
#    1730     name=name,
#    1731     if_exists=if_exists,
#    1732     index=index,
#    1733     index_label=index_label,
#    1734     schema=schema,
#    1735     dtype=dtype,
#    1736 )
#    1738 total_inserted = sql_engine.insert_records(
#    1739     table=table,
#    1740     con=self.connectable,
#    (...)
#    1747     **engine_kwargs,
#    1748 )
#    1750 self.check_case_sensitive(name=name, schema=schema)
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:1631, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1619             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1621 table = SQLTable(
#    1622     name,
#    1623     self,
#    (...)
#    1629     dtype=dtype,
#    1630 )
# -> 1631 table.create()
#    1632 return table
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:827, in SQLTable.create(self)
#     826 def create(self) -> None:
# --> 827     if self.exists():
#     828         if self.if_exists == "fail":
#     829             raise ValueError(f"Table '{self.name}' already exists.")
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:814, in SQLTable.exists(self)
#     813 def exists(self):
# --> 814     return self.pd_sql.has_table(self.name, self.schema)
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/sql.py:1760, in SQLDatabase.has_table(self, name, schema)
#    1757 def has_table(self, name: str, schema: str | None = None):
#    1758     from sqlalchemy import inspect as sqlalchemy_inspect
# -> 1760     insp = sqlalchemy_inspect(self.connectable)
#    1761     return insp.has_table(name, schema or self.meta.schema)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/inspection.py:111, in inspect(subject, raiseerr)
#     109 elif reg is True:
#     110     return subject
# --> 111 ret = reg(subject)
#     112 if ret is not None:
#     113     return ret
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/reflection.py:304, in Inspector._engine_insp(bind)
#     302 @inspection._inspects(Engine)
#     303 def _engine_insp(bind: Engine) -> Inspector:  # type: ignore[misc]
# --> 304     return Inspector._construct(Inspector._init_engine, bind)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/reflection.py:237, in Inspector._construct(cls, init, bind)
#     234     cls = bind.dialect.inspector  # type: ignore[attr-defined]
#     236 self = cls.__new__(cls)
# --> 237 init(self, bind)
#     238 return self
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/reflection.py:248, in Inspector._init_engine(self, engine)
#     246 def _init_engine(self, engine: Engine) -> None:
#     247     self.bind = self.engine = engine
# --> 248     engine.connect().close()
#     249     self._op_context_requires_connect = True
#     250     self.dialect = self.engine.dialect
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:3251, in Engine.connect(self)
#    3228 def connect(self) -> Connection:
#    3229     """Return a new :class:`_engine.Connection` object.
#    3230
#    3231     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3248
#    3249     """
# -> 3251     return self._connection_cls(self)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:147, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
# --> 147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#     150         raise
#     151 else:
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:2413, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2411 elif should_wrap:
#    2412     assert sqlalchemy_exception is not None
# -> 2413     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2414 else:
#    2415     assert exc_info[1] is not None
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 if connection is None:
#     144     try:
# --> 145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
#     147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:3275, in Engine.raw_connection(self)
#    3253 def raw_connection(self) -> PoolProxiedConnection:
#    3254     """Return a "raw" DBAPI connection from the connection pool.
#    3255
#    3256     The returned object is a proxied version of the DBAPI
#    (...)
#    3273
#    3274     """
# -> 3275     return self.pool.connect()
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:455, in Pool.connect(self)
#     447 def connect(self) -> PoolProxiedConnection:
#     448     """Return a DBAPI connection from the pool.
#     449
#     450     The connection is instrumented such that when its
#    (...)
#     453
#     454     """
# --> 455     return _ConnectionFairy._checkout(self)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:1271, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1262 @classmethod
#    1263 def _checkout(
#    1264     cls,
#    (...)
#    1267     fairy: Optional[_ConnectionFairy] = None,
#    1268 ) -> _ConnectionFairy:
#    1270     if not fairy:
# -> 1271         fairy = _ConnectionRecord.checkout(pool)
#    1273         if threadconns is not None:
#    1274             threadconns.current = weakref.ref(fairy)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:725, in _ConnectionRecord.checkout(cls, pool)
#     723 except BaseException as err:
#     724     with util.safe_reraise():
# --> 725         rec._checkin_failed(err, _fairy_was_created=False)
#     727     # not reached, for code linters only
#     728     raise
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     assert exc_value is not None
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#     149     self._exc_info = None  # remove potential circular references
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:722, in _ConnectionRecord.checkout(cls, pool)
#     719     rec = pool._do_get()
#     721 try:
# --> 722     dbapi_connection = rec.get_connection()
#     723 except BaseException as err:
#     724     with util.safe_reraise():
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:842, in _ConnectionRecord.get_connection(self)
#     840 if self.dbapi_connection is None:
#     841     self.info.clear()  # type: ignore  # our info is always present
# --> 842     self.__connect()
#     843 elif (
#     844     self.__pool._recycle > -1
#     845     and time.time() - self.starttime > self.__pool._recycle
#     846 ):
#     847     self.__pool.logger.info(
#     848         "Connection %r exceeded timeout; recycling",
#     849         self.dbapi_connection,
#     850     )
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:906, in _ConnectionRecord.__connect(self)
#     904 except BaseException as e:
#     905     with util.safe_reraise():
# --> 906         pool.logger.debug("Error on connect(): %s", e)
#     907 else:
#     908     # in SQLAlchemy 1.4 the first_connect event is not used by
#     909     # the engine, so this will usually not be set
#     910     if pool.dispatch.first_connect:
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     assert exc_value is not None
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#     149     self._exc_info = None  # remove potential circular references
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py:901, in _ConnectionRecord.__connect(self)
#     899 try:
#     900     self.starttime = time.time()
# --> 901     self.dbapi_connection = connection = pool._invoke_creator(self)
#     902     pool.logger.debug("Created new connection %r", connection)
#     903     self.fresh = True
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/create.py:636, in create_engine.<locals>.connect(connection_record)
#     633         if connection is not None:
#     634             return connection
# --> 636 return dialect.connect(*cargs, **cparams)
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/default.py:580, in DefaultDialect.connect(self, *cargs, **cparams)
#     578 def connect(self, *cargs, **cparams):
#     579     # inherits the docstring from interfaces.Dialect.connect
# --> 580     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~/.local/lib/python3.8/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) could not connect to server: Connection refused
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[48], line 2
#       1 while True:
# ----> 2     df_new=next(df_inter)
#       3     print("Inserted another chunk ..., toma")
#       4     get_ipython().run_line_magic('time', 'chunck(df_new)')
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1698, in TextFileReader.__next__(self)
#    1696 def __next__(self) -> DataFrame:
#    1697     try:
# -> 1698         return self.get_chunk()
#    1699     except StopIteration:
#    1700         self.close()
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1810, in TextFileReader.get_chunk(self, size)
#    1808         raise StopIteration
#    1809     size = min(size, self.nrows - self._currow)
# -> 1810 return self.read(nrows=size)
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1778, in TextFileReader.read(self, nrows)
#    1771 nrows = validate_integer("nrows", nrows)
#    1772 try:
#    1773     # error: "ParserBase" has no attribute "read"
#    1774     (
#    1775         index,
#    1776         columns,
#    1777         col_dict,
# -> 1778     ) = self._engine.read(  # type: ignore[attr-defined]
#    1779         nrows
#    1780     )
#    1781 except Exception:
#    1782     self.close()
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py:230, in CParserWrapper.read(self, nrows)
#     228 try:
#     229     if self.low_memory:
# --> 230         chunks = self._reader.read_low_memory(nrows)
#     231         # destructive to chunks
#     232         data = _concatenate_chunks(chunks)
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:833, in pandas._libs.parsers.TextReader.read_low_memory()
#
# StopIteration:

# %% [markdown]
# <pre>
# root@localhost:ny_taxi> select COUNT(1) from yellow_taxi_data_sql
# +---------+
# | count   |
# |---------|
# | 1469769 |
# +---------+
# SELECT 1
# Time: 0.067s
# root@localhost:ny_taxi>
#
# </pre>
